# %%
import pandas as pd
import json
import os

import sys
from pathlib import Path
sys.path.insert(0,str(Path(os.path.abspath('.')).parent.parent))
import library.validation.EnergyData.reading as reading

# %%
ticket_path_nep = "/home/lhn3e/OneDrive-3E/Research/Solar/tickets/2023/IN2946_EnergyData_measurement_data"
info_path_nep =  os.path.join(ticket_path_nep, 'info')

# %%
metadata = reading.read_metadata_for_station(info_path_nep)
# Out:
# reading hrazdanwbarmenia10minmetadata.xlsx
# reading masrikwbarmenia10minmetadata.xlsx
# reading solar-measurementspakistanhyderabadwb-esmapheader.xlsx
# reading solar-measurementspakistanislamabadwb-esmapheader.xlsx
# reading solar-measurementspakistankarachiwb-esmapheader.xlsx
# reading solar-measurementspakistankhuzdarwb-esmapheader.xlsx
# reading solar-measurementspakistanlahorewb-esmapheader.xlsx
# reading solar-measurementspakistanmultanwb-esmapheader.xlsx
# reading solar-measurementspakistanpeshawarwb-esmapheader.xlsx
# reading solar-measurementspakistanquettawb-esmapheader.xlsx
# reading solar-measurementssenegal-fatickifcheader.csv
# reading solar-measurementssenegal-kahoneifcheader.csv
# reading solar-measurementssenegal-toubaifcheader.csv
# reading solar-measurements_bangladesh_feni_wb-esmap_header.csv
# reading solar-measurements_benin-malanville_header_fr_en.xlsx
# reading solar-measurements_benin-parakou_header_fr_en.xlsx
# ...

# %%
metadata
# Out:
# [{'station name': 'Hrazdan',
#   'latitude': '40.512',
#   'longitude': '44.823',
#   'elevation (m)': 1845,
#   'time resolution': 10,
#   'time zone': 3},
#  {'station name': 'Masrik',
#   'latitude': '40.208',
#   'longitude': '45.764',
#   'elevation (m)': 1944,
#   'time resolution': 10,
#   'time zone': 3},
#  {'station name': 'PK_Solar_Hyderabad_MUET',
#   'latitude': '25.413',
#   'longitude': '68.260',
#   'elevation (m)': 60,
#   'time resolution': 10,
#   'time zone': 'UTC+5'},
#  {'station name': 'PK_Solar_Islamabad_NUST',
#   'latitude': '33.642',
#   'longitude': '72.984',
#   'elevation (m)': 500,
#   'time resolution': 10,
#   'time zone': 'UTC+5'},
#  {'station name': 'PK_Solar_Karachi_NEDUET',
#   'latitude': '24.933',
#   'longitude': '67.112',
#   'elevation (m)': 40,
#   'time resolution': 10,
#   'time zone': 'UTC+5'},
#  {'station name': 'PK_Solar_Khuzdar_BUET',
#   'latitude': '27.818',
#   'longitude': '66.629',
#   'elevation (m)': 1260,
# ...

# %%
with open(os.path.join(ticket_path_nep, 'metadata/data.json'), 'w') as f:
  json.dump(metadata, f, ensure_ascii=False)

# %%
metadata_df = pd.DataFrame(metadata)
metadata_df.to_csv(os.path.join(ticket_path_nep, 'metadata/data.csv'), index=False)
